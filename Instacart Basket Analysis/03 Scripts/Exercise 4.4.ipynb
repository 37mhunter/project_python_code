# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\37mhu\Documents\Instacart Basket Analysis'

# %%
#import orders.csv
df_ords=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col=False)

# %%
#import products.csv
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col=False)

# %%
#drop eval_set column from ords dataframe
df_ords=df_ords.drop(columns=['eval_set'])

# %%
#check days_since_prior_order value for null values
df_ords['days_since_prior_order'].value_counts(dropna=False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
#rename order_dow column to orders_day_of_week
df_ords.rename(columns = {'order_dow':'orders_day_of_week'}, inplace=True)

# %%
#check that order_dow column has been updated to orders_day_of_week
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#update order_id data type to string 
df_ords['order_id']=df_ords['order_id'].astype('str')

# %%
#
df_ords.describe()
# Out:
#             user_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01        2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01        3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01        5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
#check order_id data type
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
#import department.csv dataset
df_dep=pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'departments.csv'), index_col=False)

# %%
#review department dataframe 
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#copy department dataframe and transpose columns/rows
df_dep_t=df_dep.T

# %%
#reset transposed dataframe's index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#create new header for dep_t dataframe
new_header=df_dep_t.iloc[0]

# %%
#review new header
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#copy dep_t data from 1st to last row
df_dep_t_new=df_dep_t[1:]

# %%
#disply copied dataframe
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#assign newly created header to copied dataframe
df_dep_t_new.columns = new_header

# %%
#display new dataframe
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#create data dictionary from new department dataframe
data_dict=df_dep_t_new.to_dict('index')

# %%
#display data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#display first 5 rows from prods dataframe
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#print record where department id = 19
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
#search prods dataframe for records where department id = 19
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
#return records from prods dataframe where department id = 19
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
#assign records from prods dataframe where department ids = 19 to snacks dataframe
df_snacks=df_prods[df_prods['department_id']==19]

# %%
#display first 5 records of snacks dataframe
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#assign records from prods dataframe where department ids = 19 to snacks 2 dataframe
df_snacks_2=df_prods.loc[df_prods['department_id']==19]

# %%
##assign records from prods dataframe where department ids in list (19) to snacks 2 dataframe
df_snacks_3=df_prods.loc[df_prods['department_id'].isin([19])]

# %%
#TASK STEPS

# %%
#2 change user ID variable to string type 
df_ords['user_id']=df_ords['user_id'].astype('str')

# %%
#3 change variable name 'order_hour_of_day' to 'hour_order_placed'
df_ords.rename(columns={'order_hour_of_day':'hour_order_placed'}, inplace=True)

# %%
#4 the busiest hour for placing orders is the 10th hour
df_ords['hour_order_placed'].value_counts()
# Out:
# hour_order_placed
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
#5 - 4 is produce
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#6 create dataframe 'breakfast' for products from the breakfast department
df_breakfast=df_prods.loc[df_prods['department_id']==14]

# %%
#7 create dataframe 'party' for products from the alcohol, deli, beverages, and meat/seafood departments
df_party=df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
df_party.describe()
# Out:
#          product_id     aisle_id  department_id       prices
# count   7650.000000  7650.000000    7650.000000  7650.000000
# mean   24721.196601    66.286536       9.563268     9.012458
# std    14297.565684    36.844580       5.114123     4.997438
# min        3.000000     1.000000       5.000000     1.000000
# 25%    12402.500000    28.000000       7.000000     5.000000
# 50%    24803.000000    77.000000       7.000000     8.800000
# 75%    36977.250000    98.000000      12.000000    12.400000
# max    49684.000000   134.000000      20.000000    25.000000

# %%
#8 7650 rows 
df_party.info
# Out:
# <bound method DataFrame.info of        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
# ...

# %%
#9 create dataframe 'user1' for data related to user with user_id '1'
df_user1=df_ords.loc[df_ords['user_id']=='1']

# %%
#10 user 1 stats: user 1 has placed 11 orders/orders tend to be placed on the 2nd day of the week, at the 10th hour, and every 19 days
df_user1.describe()
# Out:
#        order_number  orders_day_of_week  hour_order_placed  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
df_ords.to_csv(os.path.join(path,'02 Data','Prepared Data','orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path,'02 Data','Prepared Data','departments_wrangled.csv'))
